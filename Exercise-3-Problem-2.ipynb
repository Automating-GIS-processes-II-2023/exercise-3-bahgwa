# %% [markdown]
# ## Problem 2: Create buffers around shopping centers (7 points)
#
# Let’s continue with our case study and calculate a 1.5 km buffer around the geocoded points.

# %% [markdown]
# ### a) Load the shopping centre data set (1 point)
#
# First, load the shopping centre *point* data set you created in *problem 1* into a `GeoDataFrame` called `shopping_centres`.

# %%
#install pathlib
# %pip install pathlib
#install pandas
# %pip install pandas
#install geopandas
# %pip install geopandas

#import pathlib
import pathlib
#import pandas
import pandas
#import geopandas
import geopandas
# Out:
# Requirement already satisfied: pathlib in /srv/conda/envs/notebook/lib/python3.10/site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: geopandas in /srv/conda/envs/notebook/lib/python3.10/site-packages (0.14.2)
# Requirement already satisfied: fiona>=1.8.21 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (2.2.0)
# Requirement already satisfied: pyproj>=3.3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (68.2.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2023.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
NOTEBOOK_PATH = pathlib.Path().resolve()
DATA_DIRECTORY = NOTEBOOK_PATH / "data"

# %%
# ADD YOUR OWN CODE HERE
shopping_centres = geopandas.read_file(
    DATA_DIRECTORY / "shopping_centres.gpkg"
)

# %%
shopping_centres.head()
# Out:
#                                              address  id       name  \
# 0  Tilexman, 1-7, Itäkatu, Itäkeskus, Vartiokylä,...   1       Itis
# 1  Jungle Juice Bar, 14-20, Mannerheimintie, Kesk...   2      Forum
# 2  Bangkok9 Iso Omena, 11, Piispansilta, Matinkyl...   3  Iso-omena
# 3  KappAhl, 3-9, Leppävaarankatu, Säteri, Etelä-L...   4      Sello
# 4  Stockmann, 3, Vantaanportinkatu, Vantaanportti...   5      Jumbo
#
#                                              addr  \
# 0            Itäkatu 1-7, 00930 Helsinki, Finland
# 1  Mannerheimintie 14–20, 00100 Helsinki, Finland
# 2           Piispansilta 11, 02230 Espoo, Finland
# 3       Leppävaarankatu 3-9, 02600 Espoo, Finland
# 4      Vantaanportinkatu 3, 01510 Vantaa, Finland
#
#                            geometry
# 0  POINT (25504582.138 6677756.530)
# 1  POINT (25496547.460 6672895.008)
# 2  POINT (25485436.273 6671983.930)
# 3  POINT (25489559.611 6678430.043)
# 4  POINT (25497943.932 6686656.982)

# %% [markdown]
# ---
#
# ### b) Create a *buffer* around the points (5 points)
#
# Calculate a 1.5 km buffer for each geocoded point. Overwrite the `geometry` column with the new buffer geometry.
#
# Use the [`geopandas.GeoDataFrame.buffer()` method](http://geopandas.org/geometric_manipulations.html#GeoSeries.buffer), that uses shapely’s [`buffer()`](http://toblerity.org/shapely/manual.html#object.buffer) in the background. You only need to care about the `distance` parameter, don’t worry about the possible other arguments.

# %%
# create buffer for each point
#update geometry column to include buffer
new_geometry = shopping_centres.buffer(1500)
shopping_centres["geometry"] = new_geometry

# %%
shopping_centres
# Out:
#                                              address  id       name  \
# 0  Tilexman, 1-7, Itäkatu, Itäkeskus, Vartiokylä,...   1       Itis
# 1  Jungle Juice Bar, 14-20, Mannerheimintie, Kesk...   2      Forum
# 2  Bangkok9 Iso Omena, 11, Piispansilta, Matinkyl...   3  Iso-omena
# 3  KappAhl, 3-9, Leppävaarankatu, Säteri, Etelä-L...   4      Sello
# 4  Stockmann, 3, Vantaanportinkatu, Vantaanportti...   5      Jumbo
# 5  Dressmann, 5, Hermannin rantatie, Verkkosaari,...   6       REDI
# 6                                               None   7     Tripla
#
#                                                 addr  \
# 0               Itäkatu 1-7, 00930 Helsinki, Finland
# 1     Mannerheimintie 14–20, 00100 Helsinki, Finland
# 2              Piispansilta 11, 02230 Espoo, Finland
# 3          Leppävaarankatu 3-9, 02600 Espoo, Finland
# 4         Vantaanportinkatu 3, 01510 Vantaa, Finland
# 5      Hermannin rantatie 5, 00580 Helsinki, Finland
# 6  Mall of Tripla, Fredikanterassi 1, 00520 Helsi...
#
#                                             geometry
# 0  POLYGON ((25506082.138 6677756.530, 25506074.9...
# 1  POLYGON ((25498047.460 6672895.008, 25498040.2...
# 2  POLYGON ((25486936.273 6671983.930, 25486929.0...
# 3  POLYGON ((25491059.611 6678430.043, 25491052.3...
# 4  POLYGON ((25499443.932 6686656.982, 25499436.7...
# 5  POLYGON ((25500308.309 6674958.748, 25500301.0...
# 6                                               None

# %%
# NON-EDITABLE CODE CELL FOR TESTING YOUR SOLUTION
assert shopping_centres.geometry.geom_type.unique() == ["Polygon"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # NON-EDITABLE CODE CELL FOR TESTING YOUR SOLUTION
# ----> 2 assert shopping_centres.geometry.geom_type.unique() == ["Polygon"]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ---
#
# ### d) Save buffer geometry layer (1 point)
#
# Save the data frame containing the buffer geometries into a new layer `buffers` inside the same *GeoPackage* `shopping_centres.gpkg`:

# %%
shopping_centres.to_file(
    DATA_DIRECTORY / "shopping_centres.gpkg", 
    layer="buffers"
)
